# %%
#import
import requests
import json
import pandas as pd

#url and data variable
url = 'https://w3qa5ydb4l.execute-api.eu-west-1.amazonaws.com/prod/finnishCoronaData/v2'
data = json.loads(requests.get(url).text)
# print(json.dumps(data, indent=1))

# %%
# normalizing the data
df = pd.json_normalize(data, 'confirmed')
df = df[['id','date','healthCareDistrict']]
df.head(2)
# Out:
#                                id                      date healthCareDistrict
# 0  HUS_2020-01-28T15:00:00.000Z_1  2020-01-28T15:00:00.000Z                HUS
# 1  HUS_2020-02-10T15:00:00.000Z_1  2020-02-10T15:00:00.000Z                HUS

# %%
# datetime formatting and checking the date
df['date']= pd.to_datetime(df['date'])
# df['date'].dtypes
df.loc[0,'date'].day_name()
# Out:
# 'Tuesday'

# %%
# every row in the data equals another case. Just added number
df['case'] = 1

# %%
# added what day of week it is
df['dayOfWeek'] = df['date'].dt.day_name()
df['dayOfWeek'].value_counts()
# Out:
# Monday       1349
# Tuesday      1338
# Wednesday    1289
# Thursday     1248
# Friday       1057
# Sunday        816
# Saturday      708
# Name: dayOfWeek, dtype: int64

# %%
# making a resample for every day, summing up the number of cases per day
casePerDay = df.resample('D', on='date').sum()
casePerDay.head()
# Out:
#                            case
# date
# 2020-01-28 00:00:00+00:00     1
# 2020-01-29 00:00:00+00:00     0
# 2020-01-30 00:00:00+00:00     0
# 2020-01-31 00:00:00+00:00     0
# 2020-02-01 00:00:00+00:00     0

# %%
# Out:
#                                               case
# healthCareDistrict date
# Vaasa              2020-03-14 00:00:00+00:00     1
#                    2020-03-15 00:00:00+00:00     2
#                    2020-03-16 00:00:00+00:00     3
#                    2020-03-17 00:00:00+00:00     4
#                    2020-03-18 00:00:00+00:00     3

# %%
casePerDayVaasa = df.loc[df['healthCareDistrict'] == 'Vaasa']
casePerDayVaasa.head()
# Out:
#                                    id                      date  \
# 298  Vaasa_2020-03-14T15:00:00.000Z_1 2020-03-14 15:00:00+00:00
# 359  Vaasa_2020-03-15T15:00:00.000Z_1 2020-03-15 15:00:00+00:00
# 360  Vaasa_2020-03-15T15:00:00.000Z_2 2020-03-15 15:00:00+00:00
# 408  Vaasa_2020-03-16T15:00:00.000Z_1 2020-03-16 15:00:00+00:00
# 409  Vaasa_2020-03-16T15:00:00.000Z_2 2020-03-16 15:00:00+00:00
#
#     healthCareDistrict  case dayOfWeek
# 298              Vaasa     1  Saturday
# 359              Vaasa     1    Sunday
# 360              Vaasa     1    Sunday
# 408              Vaasa     1    Monday
# 409              Vaasa     1    Monday

# %%
# casesperday for Vaasa
# casePerDayVaasa = casePerDayVaasa.groupby('healthCareDistrict').resample('D', on='date').sum()
# casePerDayVaasa = casePerDayVaasa.reset_index('healthCareDistrict')
casePerDayVaasa = casePerDayVaasa.set_index('date')
casePerDayVaasa.index
# Out:
# DatetimeIndex(['2020-03-14 00:00:00+00:00', '2020-03-15 00:00:00+00:00',
#                '2020-03-16 00:00:00+00:00', '2020-03-17 00:00:00+00:00',
#                '2020-03-18 00:00:00+00:00', '2020-03-19 00:00:00+00:00',
#                '2020-03-20 00:00:00+00:00', '2020-03-21 00:00:00+00:00',
#                '2020-03-22 00:00:00+00:00', '2020-03-23 00:00:00+00:00',
#                ...
#                '2020-08-05 00:00:00+00:00', '2020-08-06 00:00:00+00:00',
#                '2020-08-07 00:00:00+00:00', '2020-08-08 00:00:00+00:00',
#                '2020-08-09 00:00:00+00:00', '2020-08-10 00:00:00+00:00',
#                '2020-08-11 00:00:00+00:00', '2020-08-12 00:00:00+00:00',
#                '2020-08-13 00:00:00+00:00', '2020-08-14 00:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='date', length=154, freq=None)

# %%
# matplotlib for jupyter
# %matplotlib inline

# %%
# set date as index
df = df.set_index('date')
# casePerDay = df.resample('D').sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-ef95e07ffdd7> in <module>
#       1 # set date as index
# ----> 2 df = df.set_index('date')
#       3 casePerDay = df.resample('D').sum()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['date'] are in the columns"

# %%
# graph per day all time
casePerDay.plot()

# %%
# lineplot of July and August
casePerDay.loc['2020-07':'2020-08'].plot()

# %%
#lineplot and rolling 7 day average
import matplotlib.pyplot as plt
# Start and end of the date range to extract
start, end = '2020-06', '2020-08'
# Plot daily and weekly resampled time series together
fig, ax = plt.subplots()
ax.plot(casePerDay.loc[start:end, 'case'],
marker='.', linestyle='-', linewidth=0.5, label='Daily')
ax.plot(casePerDay.loc[start:end, 'case'].rolling(window=7).mean(),
marker='o', markersize=2, linestyle='-', label='Rolling 7 day average')
ax.set_ylabel('# of cases')
ax.legend();
print('last data date: ')  
print(casePerDay.index.max())
print('# of cases last date: ')  
print(casePerDay['case'].loc[casePerDay.index.max()])
# Out:
# last data date:
# 2020-08-18 00:00:00+00:00
# # of cases last date:
# 1

# %%
# just a simple way of writing the plot
start, end = '2020-04', '2020-08'
casePerDay['case'].plot()
casePerDay['case'].rolling(window=7).mean().plot()

# %%
#lineplot and rolling 7 day average
import matplotlib.pyplot as plt
import numpy 
import datetime as dt
# Start and end of the date range to extract
start, end = '2020-06', '2020-08'
# Plot daily and weekly resampled time series together
fig, ax = plt.subplots()
ax.plot(casePerDayVaasa.loc[start:end, 'case'],
marker='.', linestyle='-', linewidth=0.5, label='Daily')
ax.plot(casePerDayVaasa.loc[start:end, 'case'].rolling(window=7).mean(),
marker='o', markersize=2, linestyle='-', label='Rolling 7 day average')
plt.axvline(dt.datetime(2020, 8, 8))
ax.set_ylabel('# of cases')
ax.legend();
print('last data date: ')  
print(casePerDayVaasa.index.max())
print('# of cases last date: ')  
print(casePerDayVaasa['case'].loc[casePerDayVaasa.index.max()])
# Out:
# last data date:
# 2020-08-14 00:00:00+00:00
# # of cases last date:
# 2
